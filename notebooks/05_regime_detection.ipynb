# %%
import pandas as pd
import numpy as np
from hmmlearn.hmm import GaussianHMM
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/nifty_features_5min.csv")
df["datetime"] = pd.to_datetime(df["datetime"])
df = df.sort_values("datetime")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18675 entries, 0 to 18674
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   datetime             18675 non-null  datetime64[ns]
#  1   spot_open            18675 non-null  float64
#  2   spot_high            18675 non-null  float64
#  3   spot_low             18675 non-null  float64
#  4   spot_close           18675 non-null  float64
#  5   spot_volume          18675 non-null  int64
#  6   fut_open             18675 non-null  float64
#  7   fut_high             18675 non-null  float64
#  8   fut_low              18675 non-null  float64
#  9   fut_close            18675 non-null  float64
#  10  fut_volume           18675 non-null  int64
#  11  opt_open             18675 non-null  float64
#  12  opt_high             18675 non-null  float64
#  13  opt_low              18675 non-null  float64
#  14  opt_close            18675 non-null  float64
#  15  opt_volume           18675 non-null  int64
#  16  ema_5                18675 non-null  float64
#  17  ema_15               18675 non-null  float64
#  18  spot_return          18675 non-null  float64
#  19  fut_return           18675 non-null  float64
#  20  iv_proxy             18675 non-null  float64
#  21  call_delta           18675 non-null  float64
#  22  call_gamma           18675 non-null  float64
#  23  call_theta           18675 non-null  float64
#  24  call_vega            18675 non-null  float64
#  25  call_rho             18675 non-null  float64
#  26  put_delta            18675 non-null  float64
#  27  put_gamma            18675 non-null  float64
#  28  put_theta            18675 non-null  float64
#  29  put_vega             18675 non-null  float64
#  30  put_rho              18675 non-null  float64
#  31  avg_iv               18675 non-null  float64
#  32  iv_spread            18675 non-null  float64
#  33  pcr_volume           18675 non-null  float64
#  34  pcr_oi               18675 non-null  float64
#  35  futures_basis        18675 non-null  float64
#  36  delta_neutral_ratio  18675 non-null  float64
#  37  gamma_exposure       18675 non-null  float64
# dtypes: datetime64[ns](1), float64(34), int64(3)
# memory usage: 5.4 MB

# %%
df["rolling_volatility"] = df["spot_return"].rolling(20).std()

# %%
regime_features = df[
    [
        "spot_return",
        "rolling_volatility",
        "futures_basis",
        "avg_iv",
        "gamma_exposure"
    ]
].dropna()

regime_features.head()
# Out:
#     spot_return  rolling_volatility  futures_basis    avg_iv  gamma_exposure
# 19    -0.001786            0.004053            0.0  0.064347       44.305265
# 20     0.006559            0.004368            0.0  0.069341       41.170120
# 21     0.002962            0.004391            0.0  0.069709       40.956465
# 22    -0.003544            0.004425            0.0  0.070252       40.644989
# 23     0.013634            0.005450            0.0  0.086521       33.094603

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(regime_features)

# %%
hmm_model = GaussianHMM(
    n_components=3,          # 3 regimes
    covariance_type="full",
    n_iter=500,
    tol=1e-3,
    random_state=42
)

hmm_model.fit(X)
# Out:
# Model is not converging.  Current: 260863.24735731684 is not greater than 280971.672578039. Delta is -20108.425220722158
# GaussianHMM(covariance_type='full', n_components=3, n_iter=500, random_state=42,
#             tol=0.001)

# %%
regimes = hmm_model.predict(X)

regime_features["regime"] = regimes

# %%
df = df.loc[regime_features.index]
df["regime"] = regimes

df[["datetime", "regime"]].head()
# Out:
#               datetime  regime
# 19 2024-08-07 10:55:00       1
# 20 2024-08-07 11:00:00       1
# 21 2024-08-07 11:05:00       1
# 22 2024-08-07 11:10:00       1
# 23 2024-08-07 11:15:00       0

# %%
df["regime"].value_counts()
# Out:
# regime
# 1    17802
# 0      834
# 2       20
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,5))
plt.scatter(
    df["datetime"],
    df["spot_close"],
    c=df["regime"],
    cmap="viridis",
    s=5
)
plt.title("Market Regimes Detected by HMM")
plt.xlabel("Time")
plt.ylabel("NIFTY Price")
plt.show()

# %%
df.groupby("regime")[[
    "spot_return",
    "rolling_volatility",
    "avg_iv",
    "futures_basis"
]].mean()
# Out:
#         spot_return  rolling_volatility    avg_iv  futures_basis
# regime
# 0          0.004633            0.010769  0.170958            0.0
# 1         -0.000244            0.004564  0.072453            0.0
# 2          0.028429            0.124684  1.979304            0.0

# %%
regime_map = {
    0: "Range",
    1: "Trending",
    2: "Volatile"
}

df["regime_label"] = df["regime"].map(regime_map)

# %%
df.to_csv("../data/nifty_regime_5min.csv", index=False)

# %%
plt.scatter(df["datetime"], df["spot_close"], c=df["regime"])
plt.title("Market Regimes")

plt.savefig("../plots/regime_overlay.png", dpi=150, bbox_inches="tight")
plt.show()
