# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
spot = pd.read_csv("../data/nifty_spot_raw.csv")
futures = pd.read_csv("../data/nifty_futures_raw.csv")
options = pd.read_csv("../data/nifty_options_raw.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 spot = pd.read_csv("../data/nifty_spot_raw.csv")
#       2 futures = pd.read_csv("../data/nifty_futures_raw.csv")
#       3 options = pd.read_csv("../data/nifty_options_raw.csv")
#
# NameError: name 'pd' is not defined

# %%
spot.head()
spot.info()

# %%
spot.to_csv("../data/nifty_spot_5min.csv", index=False)
futures.to_csv("../data/nifty_futures_5min.csv", index=False)
options.to_csv("../data/nifty_options_5min.csv", index=False)
